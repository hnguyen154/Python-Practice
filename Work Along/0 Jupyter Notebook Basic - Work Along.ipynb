# %% [markdown]
# # Basic Jupyter Notebook Commands

# %%
# Command mode: blue mode
# Edit mode: green mode
# Command mode -> Edit mode : Press enter or you can click using mouse in the cell
# Edit mode -> Command mode : Press ESC

# CTRL + Enter = run the code within the cell
# After it runs, inside the [] will show a number

# SHIFT + Enter = run the code and move to next cell

# %%
# To add a new cell ABOVE this cell, make sure you are in Command mode, then Press "a"
# To add a new cell BELOW this cell, make sure you are in Command mode, then Press "b"
# To Delete the cell, make sure you are in Command mode, then Press "dd"

# %%
# this is a cell

# %%
# Use # to comment out the code

# For 
# Block of codes
# Highlight the block
# Then, hold CTRL + /

# %%
# To move the cell, use the arrows UP and DOWN

# %%
print('Hello')
print("World")
print('''!!!!''')
# Out:
# Hello
# World
# !!!!

# %%
# For shortcut, go into command mode, press 1/2/3/4/5 to change the level of your header

# %%
# To find and/or replace, go into command mode, Press "f"
# for more options, go into command mode, Press "h"

# %% [markdown]
# # Markdown

# %% [markdown]
# # Level 1 Header
#
# ## Level 2 Header
#
# ### Level 3 Header
#
# ###### Level 6 Header
#
# #######

# %% [markdown]
# Unordered List
#
# - Item 1
# - Item 2
#
# Ordered List
#
# 1. Lettuce
# 2. Egg
#
# HTML
#
# Below is ordered list
#
# <ol>
#     <li>Fish</li>
#     <li>Meat</li>
# </ol>
#
# Below is unordered list
#
# <ul>
#     <li>Fish</li>
#     <li>Meat</li>
# </ul>
#
# Hyperlink
#
# [Google](https://www.google.com)

# %% [markdown]
# *italic* <br>
# _italic2_
#
# **bold** <br>
# __bold__
#
# <u>Underline</u>
#
# <font color = 'red'> this is red text </font>
#
# ---
# Above is a divider
#
# <hr>
# Above is a divider
#
# <blockquote> For example, blab blab </blockquote>
#
# Latex code - codes for math symbols example: $\sqrt{x}$
#
# $\sqrt{x}$
#
# $\alpha$

# %% [markdown]
# |Name|Address|Salary|
# |-----|-------|------|
# |Hanna|Brisbane|4000|
# |Adam|Sydney|5000|

# %% [markdown]
# <table style="width:20%">
# <tr>
# <th>Name</th>
# <th>Address</th>
# <th>Salary</th>
# </tr>
#
# <tr>
# <td>Hanna</td>
# <td>Brisbane</td>
# <td>4000</td>
# </tr>
#
# <tr>
# <td>Adam</td>
# <td>Sydney</td>
# <td>5000</td>
# </tr>
# </table>

# %% [markdown]
# From your computer: Edit > Insert Image
#
# ![1255185.jpg](attachment:1255185.jpg)

# %% [markdown]
# Online: Here's a **cat** for you
# <img src="https://www.rd.com/wp-content/uploads/2020/07/35_No-regrets-1.jpg" width=400 height=400 />

# %%
# To download a package you do not have. You will use 
# "!pip3 install <package_name> --trusted-host pypi.org --trusted-host files.pythonhosted.org"
# Library name

# !pip3 install pandas --trusted-host pypi.org --trusted-host files.pythonhosted.org

# %%
import pandas

# This is importing a package and using "pd" as an alias

# %%
# How to save HTML for final project
